# %%
# 📦 Step 1: Set up Kaggle API and Download Dataset Metadata
import os
import zipfile

# Place kaggle.json in the correct path
os.environ['KAGGLE_CONFIG_DIR'] = os.getcwd()

# Download dataset from Kaggle without storing the entire file locally
# !kaggle datasets download -d bittlingmayer/amazonreviews

# Extract only a few rows for processing
with zipfile.ZipFile("amazonreviews.zip", "r") as zip_ref:
    zip_ref.extractall("amazon_data")

import pandas as pd

# Load a small sample for processing
df = pd.read_csv('amazon_data/Reviews.csv', nrows=5000)
df = df[['Summary', 'Text']]
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)
df.head()
